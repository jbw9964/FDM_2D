# %%
from FEM_2D import *

test = FEM_2D(10, 10, 1, 1)

# %%
test.build_mesh(1, 1, 1, 25, 25)
test.set_rect(5, 5, 5)
test.compile()

test.plot_status_2D(show_node=True)
# Out:
# Rectangular mesh has been set with [30] nodes.
# Mesh has been compiled.

# %%
test.set_BC_const_T(90, Y_axis=[0])
test.plot_status_2D(show_node=True)
# Out:
# Boundary condition has been set. --> [Y = [0]]

# %%
test.is_good(0.001, 1)
test.compute_steady_state(0.001)
# Out:
# [Safe to compute]
# 	==> [30]          nodes to calculate.
# 	==> [1000]        frames to repeat
# 	==> [3.00e+04]    times to calculate.
# 	==>  3.0s]     estimated.
# [Safe to compute]
# 	==> [30]          nodes to calculate.
# 	==> [100000]      frames to repeat
# 	==> [3.00e+06]    times to calculate.
# 	==>  0.0s]     estimated.
# Computing mesh... [|] --> [AVG temperature : 44.41863][=====>                        ][18325/100000]
#
# Temperature has been converged.
# [18.35400] sec to converge.
#
# Precision : [9.994010952141252e-06]
# 	==> previous temperature :  [44.41863]
# 	==> current temperature :  [44.41863]
#
# Computing has been finished.

# %%
test.plot_status_2D()
